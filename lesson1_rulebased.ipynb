# %%
# Run this every time you open the spreadsheet
# %load_ext autoreload
# %autoreload 2
from collections import Counter
import lib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load and inspect the data

# %%
# Load the data.
# This function returns "tweets", which is a list of tweets
tweets, test_tweets = lib.read_data()

# %%
# Print the number of tweets in the list
print len(tweets)

# Assign the 10th tweet to the variable "tweet" and print tweet
tweet = tweets[10]
print tweet

# To view the category of this tweet, we access tweet.category
# (This is called an attribute).
print tweet.category
# Out:
# 1120
# What we thought could never happen : Dark # Streets of # Manhattan due to power outage . # sandy # d @ 34th Street http : //t.co/081fmHg8
# Energy

# %% [markdown]
# ## Extension exercise: find the most common hashtags in the dataset

# %%
hashtags = Counter()

for t in tweets:
    for idx,token in enumerate(t):
        if token=="#":
            hashtags[t[idx+1]] += 1

print hashtags.most_common(10)
# Out:
# [(u'Sandy', 53), (u'sandy', 46), (u'HurricaneSandy', 19), (u'hurricanesandy', 11), (u'nyc', 6), (u'NYC', 5), (u'nopower', 4), (u'frankenstorm', 4), (u'SandyRelief', 3), (u'Frankenstorm', 3)]

# %%
# This function prints out all the tweets in a table, along with their category labels
lib.show_tweets(tweets)
# Out:
# <style  type="text/css" >
#     #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow0_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow0_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow1_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow1_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow2_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow2_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow3_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow3_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow4_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow4_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow5_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow5_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow6_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow6_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow7_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow7_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow8_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow8_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow9_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow9_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow10_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow10_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow11_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow11_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow12_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow12_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow13_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow13_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow14_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow14_col2 {
#             color:  pink;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow15_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow15_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow16_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow16_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow17_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow17_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow18_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow18_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow19_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow19_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow20_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow20_col2 {
#             color:  purple;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_33c8ba1c_5b00_11e7_9689_f45c89901b1brow21_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_33c8ba1c_

# %% [markdown]
# # Python refresher
#
# First, let's do some exercises to refresh our memory of a few Python concepts.
#
# ### Functions
# A Python function is written like this:
# ```
# def add_one(x):
#     return x+1
# ```
# The name of the function is `add_one`, `x` is the input variable, and the `return` keyword tells us what to give as output.

# %%
# Exercise 1. Define a function called "square_minus_1" that takes one variable (x), 
# squares it, subtracts 1, and returns the result.

#### YOUR CODE STARTS HERE ####

def square_minus_1(x):
    return x*x - 1

#### YOUR CODE ENDS HERE ####


print "Testing:"
for x in [3,-4,6.5,0]:
    print str(x) + " -> " + str(square_minus_1(x)),
    print "CORRECT" if square_minus_1(x)==(x**2-1) else "INCORRECT"
# Out:
# Testing:
# 3 -> 8 CORRECT
# -4 -> 15 CORRECT
# 6.5 -> 41.25 CORRECT
# 0 -> -1 CORRECT

# %% [markdown]
# ### If-else statements
#
# An if/else statement looks like this:
#
# ```
# if electoral_votes >= 270:
#     print "You win the election"
# else:
#     print "You lose the election"
# ```
#
# The if-statement is evaluated (`electoral_votes >= 270`); if it's true then the code under the `if` is executed, if it's false then the code under the `else` is executed.

# %%
# Exercise 2. Define a function called "contains_ss" that takes one variable (word) 
# and returns True if the word contains a double-s and False if it doesn't.
# Hint: to test whether a string e.g. "ss" is inside another string variable e.g. word, write
#    if "ss" in word:

#### YOUR CODE STARTS HERE ####

def contains_ss(word):
    if "ss" in word:
        return True
    else:
        return False

#### YOUR CODE ENDS HERE ####


print "Testing:"
for word in ["computer", "science", "lesson"]:
    print "%s ->"%word, contains_ss(word),
    print "CORRECT" if contains_ss(word)==("ss" in word) else "INCORRECT"

# Exercise as a reminder for if/else, returning from functions, substring in string testing, and/or
# Out:
# Testing:
# computer -> False CORRECT
# science -> False CORRECT
# lesson -> True CORRECT

# %% [markdown]
# ## More complex if-else statements
#
# Maybe you want to check *several* conditions? You can use an if/elif/else statement.
#
# ```
# if teamA_score > teamB_score:
#     print "Team A wins"
# elif teamA_score < teamB_score:
#     print "Team B wins"
# else:
#     print "It's a tie!"
# ```
#
# `elif` stands for "else if". In fact, the above code is just a neater way of writing this:
# ```
# if teamA_score > teamB_score:
#     print "Team A wins"
# else:
#     if teamA_score < teamB_score:
#         print "Team B wins"
#     else:
#         print "It's a tie!"
# ```
#
# You can have as many `elif` statments as you like. These are useful for when you want several options.

# %%
# Exercise 3. Define a function called "grade" that takes one input (score).
# If score >= 90, return the string "A"
# Otherwise, if score >= 80, return the string "B"
# Otherwise, if score >= 70, return the string "C"
# Otherwise, if score >= 60, return the string "D"
# Otherwise, if score >= 50, return the string "E"
# Otherwise, return the string "F"

#### YOUR CODE STARTS HERE ####

def grade(score):
    if score>=90:
        return "A"
    elif score>=80:
        return "B"
    elif score>=70:
        return "C"
    elif score>=60:
        return "D"
    elif score>=50:
        return "E"
    else:
        return "F"

#### YOUR CODE ENDS HERE ####


print "Testing:"
for (score,g) in [(77,"C"),(80,"B"),(32,"F"),(100,"A"),(69,"D")]:
    print "%i -> %s" % (score, grade(score)),
    print "CORRECT" if grade(score)==g else "INCORRECT"
# Out:
# Testing:
# 77 -> C CORRECT
# 80 -> B CORRECT
# 32 -> F CORRECT
# 100 -> A CORRECT
# 69 -> D CORRECT

# %% [markdown]
# # Write a rule-based tweet classifier
#
# Time to write our rule-based classifier!
# The function below uses a `if/elif/else` statement to return the predicted category of a tweet.
#
# Fill in the missing `if` and `elif` statements with something sensible (there is no one right answer)!

# %%
def classify_rb(tweet):
    
  tweet_text = str(tweet).lower() # this makes the tweet lower-case, so we don't have to worry about matching case

  if 'medical' in tweet_text:
    return "Medical"
  elif 'energy' in tweet_text:
    return "Energy"
  elif 'water' in tweet_text:
    return "Water"
  elif 'food' in tweet_text:
    return "Food"
  else:
    return "None"

# %% [markdown]
# # Test your rule-based classifier on some examples
#
# Run the cell below to see the results of your rule-based classifier.
# You should see a table showing each tweet, along with its true category and the category predicted by your system.
#
# Which types of tweets does your system get right? Which types of tweets does your system get wrong and why?
#
# How would you measure the accuracy of your system?

# %%
predictions = [(tweet, classify_rb(tweet)) for tweet in test_tweets] # a list of (tweet, prediction) pairs

lib.show_predictions(predictions)
# Out:
# <style  type="text/css" >
#     #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow0_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow0_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow1_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow1_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow2_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow2_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow3_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow3_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow4_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow4_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow5_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow5_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow6_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow6_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow7_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow7_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow8_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow8_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow9_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow9_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow10_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow10_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow11_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow11_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow12_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow12_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow13_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow13_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow14_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow14_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow15_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow15_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow16_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow16_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow17_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow17_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow18_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow18_col2 {
#             color:  blue;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow19_col1 {
#             color:  red;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow19_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow20_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow20_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_390b8d75_5b00_11e7_90f8_f45c89901b1brow21_col1 {
#             color:  green;
#             text-align:  left;
#         }    #T_39

# %% [markdown]
# # Break your rule-based classifier!
#
# FOOL THE RULES!

# %%
def classify_rb_game(tweet):
    
  tweet_text = str(tweet).lower() # this makes the tweet lower-case, so we don't have to worry about matching case

  if 'medical' in tweet_text or 'doctor' in tweet_text:
    return "Medical"
  elif 'energy' in tweet_text:
    return "Energy"
  elif 'water' in tweet_text:
    return "Water"
  elif 'food' in tweet_text:
    return "Food"
  else:
    return "None"

# %% [markdown]
# ### Write a tweet about Food that will be misclassified
#
# Below, write a disaster-scenario tweet about Food that the classification function above will get wrong (i.e. fail to recognize it's about food).
#
# Hint: think of less-obvious food-related keywords that aren't included in the rule-based system above.
#
# Then run the cell - make sure the tweet is classified as something other than Food!

# %%
food_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(food_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet about Energy that will be misclassified

# %%
energy_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(energy_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet about Water that will be misclassified

# %%
water_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(water_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet about Medical that will be misclassified

# %%
medical_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(medical_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet NOT about Food, that will be falsely classified as Food
#
# Below, write a tweet that is NOT about Food, but that the classifier above will classify as Food.
#
# Hint: you want to trick the classifier into thinking you're talking about food when you're not. Look at the keywords the rule-based system associates with food. Can you find a way to use them while actually talking about not-food? For example, if the system looks for the word "food" you could write "Reading Plato. Food for thought.". If the system looks for the word "cook", you could write "I hear the power's out in Cook County."
#
# Then run the cell - make sure the tweet is classified as Food!

# %%
not_food_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(not_food_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet NOT about Energy, that will be falsely classified as Energy

# %%
not_energy_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(not_energy_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet NOT about Water, that will be falsely classified as Water

# %%
not_water_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(not_water_tweet)
# Out:
# This tweet is classified as: None

# %% [markdown]
# ### Write a tweet NOT about Medical, that will be falsely classified as Medical

# %%
not_medical_tweet = ""
print "This tweet is classified as: %s\n" % classify_rb_game(not_medical_tweet)
# Out:
# This tweet is classified as: None
