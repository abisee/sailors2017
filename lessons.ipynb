# %%
# Run this every time you open the spreadsheet
# %load_ext autoreload
# %autoreload 2
import lib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load and inspect the data

# %%
# Load the data.
# This function returns "tweets", which is a list of tweets
tweets, test_tweets = lib.read_data()

# %%
# Print the number of tweets in the list
print len(tweets)

# Assign the 10th tweet to the variable "tweet" and print tweet
tweet = tweets[10]
print tweet

# To view the category of this tweet, we access tweet.category
# (This is called an attribute).
print tweet.category
# Out:
# 1120
# Officially have no power ... .just fckin great . # FckYouSandy
# None

# %%
# This function prints out all the tweets in a table, along with their category labels

lib.show_tweets(tweets)
# Out:
#         <style  type="text/css" >
#
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow0_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow0_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow0_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow1_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow1_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow1_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow2_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow2_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow2_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow3_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow3_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow3_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow4_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow4_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow4_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow5_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow5_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow5_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow6_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow6_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow6_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow7_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow7_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow7_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow8_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow8_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow8_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow9_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow9_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow9_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow10_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow10_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow10_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow11_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow11_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow11_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow12_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow12_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow12_col2 {
#
#                 color:  pink;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow13_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow13_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow13_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow14_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow14_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow14_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow15_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow15_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow15_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow16_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow16_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow16_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow17_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow17_col1 {
#
#                 color:  blue;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow17_col2 {
#
#                 color:  purple;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901b1brow18_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_2a1f55cf_5a40_11e7_89a8_f45c89901

# %% [markdown]
# # Python refresher
#
# First, let's do some exercises to refresh our memory of a few Python concepts.
#
# ### Functions
# A Python function is written like this:
# ```
# def add_one(x):
#     return x+1
# ```
# The name of the function is `add_one`, `x` is the input variable, and the `return` keyword tells us what to give as output.

# %%
# Exercise 1. Define a function called "square_minus_1" that takes one variable (x), 
# squares it, subtracts 1, and returns the result.

#### YOUR CODE STARTS HERE ####

def square_minus_1(x):
    return x*x - 1

#### YOUR CODE ENDS HERE ####


print "Testing:"
for x in [3,-4,6.5,0]:
    print str(x) + " -> " + str(square_minus_1(x)),
    print "CORRECT" if square_minus_1(x)==(x**2-1) else "INCORRECT"
# Out:
# Testing:
# 3 -> 8 CORRECT
# -4 -> 15 CORRECT
# 6.5 -> 41.25 CORRECT
# 0 -> -1 CORRECT

# %% [markdown]
# ### If-else statements
#
# An if/else statement looks like this:
#
# ```
# if electoral_votes >= 270:
#     print "You win the election"
# else:
#     print "You lose the election"
# ```
#
# The if-statement is evaluated (`electoral_votes >= 270`); if it's true then the code under the `if` is executed, if it's false then the code under the `else` is executed.

# %%
# Exercise 2. Define a function called "contains_ss" that takes one variable (word) 
# and returns True if the word contains a double-s and False if it doesn't.
# Hint: to test whether a string e.g. "ss" is inside another string variable e.g. word, write
#    if "ss" in word:

#### YOUR CODE STARTS HERE ####

def contains_ss(word):
    if "ss" in word:
        return True
    else:
        return False

#### YOUR CODE ENDS HERE ####


print "Testing:"
for word in ["computer", "science", "lesson"]:
    print "%s ->"%word, contains_ss(word),
    print "CORRECT" if contains_ss(word)==("ss" in word) else "INCORRECT"

# Exercise as a reminder for if/else, returning from functions, substring in string testing, and/or
# Out:
# Testing:
# computer -> False CORRECT
# science -> False CORRECT
# lesson -> True CORRECT

# %% [markdown]
# ## More complex if-else statements
#
# Maybe you want to check *several* conditions? You can use an if/elif/else statement.
#
# ```
# if teamA_score > teamB_score:
#     print "Team A wins"
# elif teamA_score < teamB_score:
#     print "Team B wins"
# else:
#     print "It's a tie!"
# ```
#
# `elif` stands for "else if". In fact, the above code is just a neater way of writing this:
# ```
# if teamA_score > teamB_score:
#     print "Team A wins"
# else:
#     if teamA_score < teamB_score:
#         print "Team B wins"
#     else:
#         print "It's a tie!"
# ```
#
# You can have as many `elif` statments as you like. These are useful for when you want several options.

# %%
# Exercise 3. Define a function called "grade" that takes one input (score).
# If score >= 90, return the string "A"
# Otherwise, if score >= 80, return the string "B"
# Otherwise, if score >= 70, return the string "C"
# Otherwise, if score >= 60, return the string "D"
# Otherwise, if score >= 50, return the string "E"
# Otherwise, return the string "F"

#### YOUR CODE STARTS HERE ####

def grade(score):
    if score>=90:
        return "A"
    elif score>=80:
        return "B"
    elif score>=70:
        return "C"
    elif score>=60:
        return "D"
    elif score>=50:
        return "E"
    else:
        return "F"

#### YOUR CODE ENDS HERE ####


print "Testing:"
for (score,g) in [(77,"C"),(80,"B"),(32,"F"),(100,"A"),(69,"D")]:
    print "%i -> %s" % (score, grade(score)),
    print "CORRECT" if grade(score)==g else "INCORRECT"
# Out:
# Testing:
# 77 -> C CORRECT
# 80 -> B CORRECT
# 32 -> F CORRECT
# 100 -> A CORRECT
# 69 -> D CORRECT

# %% [markdown]
# # Write a rule-based tweet classifier
#
# Time to write our rule-based classifier!
# The function below uses a `if/elif/else` statement to return the predicted category of a tweet.
#
# Fill in the missing `if` and `elif` statements with something sensible (there is no one right answer)!

# %%
def classify_rb(tweet):
    
  tweet_text = str(tweet).lower() # this makes the tweet lower-case, so we don't have to worry about matching case

  if _______:
    return "Medical"
  elif _______:
    return "Energy"
  elif _______:
    return "Water"
  elif _______:
    return "Food"
  else:
    return "None"

# %% [markdown]
# # Test your rule-based classifier on some examples
#
# Run the cell below to see the results of your rule-based classifier.
# You should see a table showing each tweet, along with its true category and the category predicted by your system.
#
# Which types of tweets does your system get right? Which types of tweets does your system get wrong and why?
#
# How would you measure the accuracy of your system?

# %%
predictions = [(tweet, classify_rb(tweet)) for tweet in test_tweets] # a list of (tweet, prediction) pairs

lib.show_predictions(predictions)
# Out:
#         <style  type="text/css" >
#
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow0_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow0_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow0_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow1_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow1_col1 {
#
#                 color:  blue;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow1_col2 {
#
#                 color:  blue;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow2_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow2_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow2_col2 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow3_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow3_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow3_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow4_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow4_col1 {
#
#                 color:  green;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow4_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow5_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow5_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow5_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow6_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow6_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow6_col2 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow7_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow7_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow7_col2 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow8_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow8_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow8_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow9_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow9_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow9_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow10_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow10_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow10_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow11_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow11_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow11_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow12_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow12_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow12_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow13_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow13_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow13_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow14_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow14_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow14_col2 {
#
#                 color:  blue;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow15_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow15_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow15_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow16_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow16_col1 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow16_col2 {
#
#                 color:  gray;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow17_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow17_col1 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow17_col2 {
#
#                 color:  orange;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow18_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_329b5599_5a40_11e7_a457_f45c89901b1brow18_col1 {

# %% [markdown]
# # Measure the accuracy of your rule-based classifier
#
# Complete the function below to calculate the precision, recall and F1 for a category.

# %%
def evaluate(predictions, c):
    """
    Inputs:
        predictions: a list of (tweet, predicted_category) pairs
        c: a category 
    Calculate the precision, recall and F1 for a single category c (e.g. Food)
    """
    
    true_positives = 0.0
    false_positives = 0.0
    false_negatives = 0.0
    
    for (tweet, predicted_category) in predictions:
        true_category = tweet.category
        if true_category == c and predicted_category == c:
            true_positives += 1
        elif true_category == c and predicted_category != c:
            false_negatives += 1
        elif true_category != c and predicted_category == c:
            false_positives += 1
            
    if true_positives == 0:
        precision = 0.0
        recall = 0.0
        f1 = 0.0
    else:
        precision = true_positives*100 / (true_positives + false_positives)
        recall = true_positives*100 / (true_positives + false_negatives)
        f1 = 2*precision*recall / (precision + recall)

    print c
    print "Precision: ", precision
    print "Recall: ", recall
    print "F1: ", f1
    print ""
#     print "Class %s: precision %.2f, recall %.2f, F1 %.2f" % (c, precision, recall, f1)

    return f1

# %%
predictions = [(tweet, classify_rb(tweet)) for tweet in test_tweets] # maps each unseen tweet to its predicted label

food_f1 = evaluate(predictions, "Food")
water_f1 = evaluate(predictions, "Water")
energy_f1 = evaluate(predictions, "Energy")
medical_f1 = evaluate(predictions, "Medical")
none_f1 = evaluate(predictions, "None")

average_f1 = (food_f1 + water_f1 + energy_f1 + medical_f1 + none_f1)/5
print "Average F1: ", average_f1
# Out:
# Food
# Precision:  82.4
# Recall:  74.6376811594
# F1:  78.3269961977
#
# Water
# Precision:  75.8620689655
# Recall:  100.0
# F1:  86.2745098039
#
# Energy
# Precision:  0.0
# Recall:  0.0
# F1:  0.0
#
# Medical
# Precision:  100.0
# Recall:  15.3846153846
# F1:  26.6666666667
#
# None
# Precision:  40.8
# Recall:  67.1052631579
# F1:  50.7462686567
#
# Average F1:  48.402888265

# %% [markdown]
# ## Look at the confusion matrix
#
# * Rows represent the true category of the tweet
# * Columns represent the category predicted by your classifier
# * So numbers on the diagonal represent correct classifications, and off-diagonal numbers represent misclassification

# %%
lib.show_confusion_matrix(predictions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energy</th>
#       <th>Food</th>
#       <th>Medical</th>
#       <th>None</th>
#       <th>Water</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Energy</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>31</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Food</th>
#       <td>0</td>
#       <td>103</td>
#       <td>0</td>
#       <td>32</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Medical</th>
#       <td>0</td>
#       <td>0</td>
#       <td>2</td>
#       <td>11</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>None</th>
#       <td>0</td>
#       <td>22</td>
#       <td>0</td>
#       <td>51</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>Water</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Break your rule-based classifier!

# %%
def classify_rb_game(tweet):
  tweet_text = str(tweet).lower()
  if "food" in tweet_text or "hungry" in tweet_text or "meal" in tweet_text or "snacks" in tweet_text or "eat" in tweet_text:
    return 'Food'
  elif "medical" in tweet_text or "medicine" in tweet_text or "injury" in tweet_text or "hospital" in tweet_text:
    return 'Medical'
  elif "energy" in tweet_text or "power" in tweet_text or "electricity" in tweet_text or "phone" in tweet_text:
    return 'Energy'
  elif "water" in tweet_text or "thirsty" in tweet_text or "drink" in tweet_text:
    return 'Water'
  else:
    return 'None'

# %% [markdown]
# ### Write a tweet about Energy that will be misclassified

# %%
energy_tweet = "I need to call my relatives to check they're OK but I can't charge my phone #sandy"
print "This tweet is classified as: %s\n" % classify_rb_game(energy_tweet)
# Out:
# This tweet is classified as: Energy

# %% [markdown]
# ### Write a tweet about Food that will be misclassified

# %%
food_tweet = "I'm starving... need a power drink!"
print "This tweet is classified as: %s\n" % classify_rb_game(food_tweet)
# Out:
# This tweet is classified as: Energy

# %% [markdown]
# ### Write a tweet NOT about Medical that will be classified as Medical

# %%
not_medical_tweet = "#HurricaneSandy is so boring but I'm listening to Doctor Dre"
print "This tweet is classified as: %s\n" % classify_rb_game(not_medical_tweet)
# Out:
# This tweet is classified as: None
