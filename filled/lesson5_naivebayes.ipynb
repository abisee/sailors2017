# %%
# Run this every time you open the spreadsheet
# %load_ext autoreload
# %autoreload 2
from collections import Counter
import lib

# %% [markdown]
# # Load and inspect the data

# %%
# Load the data.
# This function returns tweets and test_tweets, both lists of tweets
tweets, test_tweets = lib.read_data()

# %% [markdown]
# # Learn a Naive Bayes classifier
#
# To construct our Naive Bayes classifier, we first need to calculate two things:
#
# ### Prior probabilities of categories
# We need to calculate $P(C_i)$ for each category $C_i \in \{\text{Energy}, \text{Food}, \text{Medical}, \text{Water}, \text{None}\}$.
#
# We estimate $P(C_i)$ by $\frac{\text{# tweets about }C_i}{\text{# tweets}}$
#
# ### Conditional probabilities of tokens
# For each token (i.e. word) $x_j$ and each category $C_i$, we need to calculate $P(x_j|C_i)$.
#
# We estimate $P(x_j|C_i) = \frac{P(x_j \text{ and } C_i)}{P(C_i)}$ by $\frac{\text{# tweets about }C_i \text{ containing }x_j}{\text{# tweets about }C_i}$

# %%
# Exercise 1, step-by-step version (challenge version is below).

# The function below has two arguments: a list of tweets, and a category c
# which is a string equal to one of "Energy", "Food", "Medical", "Water", "None".
# The function should calculate the two things described above.
# Fill in the blanks.


def calc_probs(tweets, c):
    """
    Input:
        tweets: a list of tweets
        c: a string representing a category; one of "Energy", "Food", "Medical", "Water", "None". 
    Returns:
        prob_c: the prior probability of category c
        token_probs: a Counter mapping each token to P(token|category c)
    """
    
    # Step 1: Calculate the total number of tweets
    num_tweets = len(tweets)

    
    # Step 2: Calculate the number of tweets that are about category c.
    # Save the answer to a variable called num_tweets_about_c.
    # Remember c is a string, and you can get the category of a tweet via tweet.category
    num_tweets_about_c = len([t for t in tweets if t.category==c])

    
    
    # Step 3: Calculate the probability of category c using the answers from Steps 1 and 2.
    # Hint: be careful when you divide two integers!
    prob_c = float(num_tweets_about_c)/num_tweets
    
    
    # Step 4: Create an empty Counter called token_counts.
    # (We will use it to map each token to the number of category-c tweets containing that token.)
    token_counts = Counter()
    
    
    # Step 5 (tricky): Use a for-loop to iterate over the list of tweets.
    # Use an if-statement to check whether the tweet is in category c.
    # If it is, iterate over the tokens of the tweet (which you can access via tweet.tokenSet) using a for-loop.
    # For each token, increment its count in token_counts.
    for tweet in tweets:
        if tweet.category==c:
            for token in tweet.tokenSet:
                token_counts[token] += 1
    
    
    
    # Step 6: Create an empty Counter called token_probs.
    # (We will use it to map each token to P(token | category c), 
    # i.e. the fraction of all category-c tweets that contain the token)
    token_probs = Counter()
    
    
    # Step 7: Now fill token_probs.
    # For each token->count in token_counts, you want to add token->fraction to token_probs.
    # Use a for-loop over token_counts. 
    # Remember that when you iterate over a dictionary/Counter, you access the keys.
    # You'll need to use the variable num_tweets_about_c.
    # Be careful when you divide integers!
    for token,count in token_counts.iteritems():
        token_probs[token] = float(count)/num_tweets_about_c

    
    
    print "Class %s has prior probability %.2f" % (c, prob_c)    
    return prob_c, token_probs


prob_food, token_probs_food = calc_probs(tweets, "Food")
prob_water, token_probs_water = calc_probs(tweets, "Water")
prob_energy, token_probs_energy = calc_probs(tweets, "Energy")
prob_medical, token_probs_medical = calc_probs(tweets, "Medical")
prob_none, token_probs_none = calc_probs(tweets, "None")
# Out:
# Class Food has prior probability 0.47
# Class Water has prior probability 0.09
# Class Energy has prior probability 0.12
# Class Medical has prior probability 0.04
# Class None has prior probability 0.28

# %%
# Exercise 1, challenge version (step-by-step version is above).

# Implement the function!

# Reminders:
#   tweet.category gets you the category of a tweet (as a string)
#   tweet.tokenSet gets you the set of tokens in a tweet (lowercased).
#     You can iterate over a set just like a list using a for-loop.


def calc_probs(tweets, c):
    """
    Input:
        tweets: a list of tweets
        c: a string representing a category; one of "Energy", "Food", "Medical", "Water", "None". 
    Returns:
        prob_c: the prior probability of category c
        token_probs: a Counter mapping each token to P(token|category c)
    """
    
    ##### YOUR CODE STARTS HERE ####
    
    
    
    
    
    
    ##### YOUR CODE ENDS HERE ####
            
    print "Class %s has prior probability %.2f" % (c, prob_c)
    
    ##### OPTIONAL EXERCISE STARTS HERE ####
    
    # Write some code to nicely-print the top most common tokens for this category.
    # Note that token_probs.most_common(10) gives you the 10 most common tokens in the counter,
    # as a list of (token, probability) pairs. This is another convenient feature of Counters!
    
    
    
    ##### OPTIONAL EXERCISE ENDS HERE ####

    return prob_c, token_probs


prob_food, token_probs_food = calc_probs(tweets, "Food")
prob_water, token_probs_water = calc_probs(tweets, "Water")
prob_energy, token_probs_energy = calc_probs(tweets, "Energy")
prob_medical, token_probs_medical = calc_probs(tweets, "Medical")
prob_none, token_probs_none = calc_probs(tweets, "None")

# %% [markdown]
# ### See what your model has learnt

# %%
# For each category c, print out the tokens that maximize P(c|token)

token_probs = {'Food': token_probs_food, 'Water': token_probs_water, 'Energy': token_probs_energy, 'Medical': token_probs_medical,'None': token_probs_none}
prior_probs = {'Food': prob_food, 'Water': prob_water, 'Energy': prob_energy, 'Medical': prob_medical, 'None': prob_none}
lib.most_discriminative(tweets, token_probs, prior_probs)
# Out:
# MOST DISCRIMINATIVE TOKENS:
#
# TOKEN                P(Energy|token)
# powers               0.8029
# dark                 0.8029
# generator            0.7654
# batteries            0.7559
# sandysucks           0.7534
# class                0.7534
# flashlights          0.7345
# masks                0.7334
# 11/3                 0.6736
# told                 0.6707
#
# TOKEN                P(Food|token)
# canned               0.9784
# non-perishable       0.9767
# serve                0.9663
# perishable           0.9562
# cook                 0.9511
# soup                 0.9489
# sandwiches           0.9489
# rice                 0.9441
# thanksgiving         0.9441
# meal                 0.9383
#
# TOKEN                P(Medical|token)
# meds                 0.8229
# aid                  0.8008
# ups                  0.7360
# medicine             0.7360
# ointment             0.7360
# medications          0.7360
# prescription         0.7360
# 4t-5t                0.7360
# pull                 0.6596
# kits                 0.6596
#
# TOKEN                P(None|token)
# ..                   0.9531
# everyone             0.8955
# feel                 0.8809
# last                 0.8809
# im                   0.8618
# irene                0.8604
# ...                  0.8601
# thing                0.8314
# crazy                0.8314
# wonder               0.8314
#
# TOKEN                P(Water|token)
# bottled              0.9059
# gallon               0.8307
# jugs                 0.7970
# water                0.7873
# gallons              0.7266
# pallets              0.6625
# flood                0.6625
# liter                0.6625
# feet                 0.6625
# spring               0.6625

# %% [markdown]
# # Build a Naive Bayes classifier
#
# Now we've calculated $P(C_i)$ and $P(x_j|C_i)$, we can classify any tweet!
#
# Given a tweet which is a set of tokens $\{x_1,...,x_n\}$, the posterior probability of each category $C_i$ is
#
# $P(C_i | x_1,...,x_n) \propto P(C_i) \times P(x_1|C_i) \times P(x_2|C_i) ... \times P(x_n|C_i)$
#
# We just need to calculate this for each category then determine which is largest.

# %%
# Exercise 2. 

# Complete this function that calculates the posterior probability of P(c|tweet).

def get_posterior_prob(tweet, prob_c, token_probs):
    """Calculate the posterior P(c|tweet). 
    (Actually, calculate something proportional to it).
    
    Inputs:
        tweet: a tweet
        prob_c: the prior probability of category c
        token_probs: a Counter mapping each token P(token|c)
    Return:
        The posterior P(c|tweet).
    """

    ##### YOUR CODE STARTS HERE #####
    
    # Hint: first set posterior to prob_c, then use a for-loop over tweet.tokenSet
    # to repeatedly multiply posterior by P(token|c)
        
    posterior = prob_c
    for token in tweet.tokenSet:
        if token_probs[token]==0:
            posterior *= 0.001
        else:
            posterior *= token_probs[token]
        
    ##### YOUR CODE ENDS HERE #####
    
    return posterior



# Now you've written the function, look at the output for P(Energy|"No power in Riverdale").
# What's gone wrong? 
# Try editing your function above to print out each token and token_probs[token].
# Can you see what went wrong? How might you fix it?

riverdale_tweet = lib.Tweet("No power in Riverdale", "Energy", "need")
print "P(Energy|'No power in Riverdale') = ", get_posterior_prob(riverdale_tweet, prob_energy, token_probs_energy)
# Out:
# P(Energy|'No power in Riverdale') =  2.80600189036e-06

# %%
# This cell defines the classification function, that takes a tweet 
# and decides which category is most likely using the posteriors you just calculated.


# OPTIONAL EXERCISE (come back to it once you've reached the end of the notebook).
# Rewrite this function to be less repetitive i.e. don't repeat things 5 times.
# There are several possible solutions; you might want to use lists or dictionaries.
# You might also want to rewrite the earlier code that computed prob_food, token_probs_food etc.


def classify_nb(tweet):
    """Classifies a tweet. Calculates the posterior P(c|tweet) for each category c, 
    and returns the category with largest posterior.
    Input:
        tweet
    Output:
        string equal to most-likely category for this tweet
    """
    posterior_food_prob = get_posterior_prob(tweet, prob_food, token_probs_food)
    posterior_water_prob = get_posterior_prob(tweet, prob_water, token_probs_water)
    posterior_energy_prob = get_posterior_prob(tweet, prob_energy, token_probs_energy)
    posterior_medical_prob = get_posterior_prob(tweet, prob_medical, token_probs_medical)
    posterior_none_prob = get_posterior_prob(tweet, prob_none, token_probs_none)
    
    max_posterior = max([posterior_food_prob, posterior_water_prob, posterior_energy_prob, posterior_medical_prob, posterior_none_prob])
    if posterior_food_prob == max_posterior:
        return 'Food'
    elif posterior_water_prob == max_posterior:
        return 'Water'
    elif posterior_energy_prob == max_posterior:
        return 'Energy'
    elif posterior_medical_prob == max_posterior:
        return 'Medical'
    else:
        return 'None'

# %% [markdown]
# ## Evaluate the Naive Bayes classifier

# %%
# Compare true labels and predicted labels in a table

predictions = [(tweet, classify_nb(tweet)) for tweet in test_tweets] # a list of (tweet, prediction) pairs
lib.show_predictions(predictions)
# Out:
# <style  type="text/css" >
#     #T_a206761c_7bae_11e7_afcf_f45c89901b1brow0_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow0_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow0_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow1_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow1_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow1_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow2_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow2_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow2_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow3_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow3_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow3_col2 {
#             color:  blue;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow4_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow4_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow4_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow5_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow5_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow5_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow6_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow6_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow6_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow7_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow7_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow7_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow8_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow8_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow8_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow9_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow9_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow9_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow10_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow10_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow10_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow11_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow11_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow11_col2 {
#             color:  red;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow12_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow12_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow12_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow13_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow13_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow13_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow14_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow14_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow14_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow15_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow15_col1 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow15_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow16_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow16_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow16_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow17_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow17_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow17_col2 {
#             color:  red;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow18_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow18_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow18_col2 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow19_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow19_col1 {
#             color:  blue;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow19_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow20_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow20_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow20_col2 {
#             color:  orange;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow21_col0 {
#             color:  black;
#             text-align:  left;
#         }    #T_a206761c_7bae_11e7_afcf_f45c89901b1brow21_col1 {
#             color:  gray;
#             text-align:  left;
#         }    #T_a206761

# %%
# Get average F1 score for the test set

predictions = [(tweet, classify_nb(tweet)) for tweet in test_tweets] # maps each test tweet to its predicted label
lib.evaluate(predictions)
# Out:
# Energy
# Precision:  50.0
# Recall:  60.0
# F1:  54.5454545455
#
# Food
# Precision:  83.5616438356
# Recall:  94.5736434109
# F1:  88.7272727273
#
# Medical
# Precision:  85.7142857143
# Recall:  46.1538461538
# F1:  60.0
#
# None
# Precision:  82.8571428571
# Recall:  73.417721519
# F1:  77.8523489933
#
# Water
# Precision:  80.0
# Recall:  40.0
# F1:  53.3333333333
#
# Average F1:  66.8916819199

# %%
# Get average F1 score for the TRAINING set.
# Compare with average F1 for test set above. What's the reason for the difference?

trainset_predictions = [(tweet, classify_nb(tweet)) for tweet in tweets] # maps each training tweet to its predicted label
lib.evaluate(trainset_predictions)
# Out:
# Energy
# Precision:  91.3333333333
# Recall:  99.2753623188
# F1:  95.1388888889
#
# Food
# Precision:  96.6355140187
# Recall:  97.9166666667
# F1:  97.2718720602
#
# Medical
# Precision:  97.7777777778
# Recall:  100.0
# F1:  98.8764044944
#
# None
# Precision:  97.9865771812
# Recall:  94.498381877
# F1:  96.2108731466
#
# Water
# Precision:  100.0
# Recall:  91.0891089109
# F1:  95.3367875648
#
# Average F1:  96.566965231

# %%
lib.show_confusion_matrix(predictions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Energy</th>
#       <th>Food</th>
#       <th>Medical</th>
#       <th>None</th>
#       <th>Water</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Energy</th>
#       <td>24</td>
#       <td>8</td>
#       <td>0</td>
#       <td>7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Food</th>
#       <td>2</td>
#       <td>122</td>
#       <td>0</td>
#       <td>4</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Medical</th>
#       <td>3</td>
#       <td>4</td>
#       <td>6</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>None</th>
#       <td>18</td>
#       <td>2</td>
#       <td>1</td>
#       <td>58</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Water</th>
#       <td>1</td>
#       <td>10</td>
#       <td>0</td>
#       <td>1</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
